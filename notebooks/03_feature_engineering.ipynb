# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import pandas as pd

from src.feature_engineering import (
    drop_customer_id,
    split_features_target,
    encode_features,
    split_train_test,
    scale_features, 
    save_processed_data
)

# %%
data = pd.read_csv("../data/telco_customer_churn_clean.csv")

# %%
data = drop_customer_id(data)

# %%
X, y = split_features_target(data, target_column="Churn")

# %%
X_encoded = encode_features(X)

# %%
X_train, X_test, y_train, y_test = split_train_test(X_encoded, y)

# %%
X_train_scaled, X_test_scaled, scaler = scale_features(X_train, X_test)

# %%
# After encoding
encoded_data = X_encoded.copy()
encoded_data["Churn"] = y

save_processed_data(
    encoded_data,
    "../data/telco_feature_engineered.csv"
)
